# %%
import csv
import random
import json

csvfile = open('./Domestic Exchange.csv')
reader = csv.DictReader(csvfile)
nodes = []
edges = []
nodeDict = {}
for row in reader:
    colorgen = "%06x" % random.randint(0, 0xFFFFFF)
    if row['ASN'] not in nodeDict:
        node = {
            "color": colorgen,
            "label": row['Name'],
            "attributes": {},
            "x": random.randint(-1000,1000),
            "y": random.randint(-1000,1000),
            "id": row['ASN'],
        }
        nodes.append(node)
        nodeDict[row['ASN']] = 1
    else:
        nodeDict[row['ASN']] += 1
    if row['ASN-source'] not in nodeDict:
        nodeDict[row['ASN-source']] = 1
    else:
        nodeDict[row['ASN-source']] += 1
    edge = {
        "sourceID": row['ASN-source'],
        "attributes": {},
        "targetID": row['ASN'],
        "size": float(row['Bandwidth'])/10,
    }
    edges.append(edge)
for node in nodes:
    node["size"] = nodeDict[node['id']]
    
data = {
    "nodes": nodes,
    "edges": edges,
}
json.dumps(data)
# Out:
# '{"nodes": [{"color": "b3fed9", "label": "CSL-IX", "attributes": {}, "x": 171, "y": -42, "id": "AS45265", "size": 20}, {"color": "bd59ad", "label": "TIG-IX", "attributes": {}, "x": 979, "y": 565, "id": "AS38081", "size": 25}, {"color": "06d1c9", "label": "TCCT-IX", "attributes": {}, "x": -5, "y": -40, "id": "AS45667", "size": 21}, {"color": "3baa51", "label": "Jastel-IX", "attributes": {}, "x": -248, "y": -672, "id": "AS45642", "size": 24}, {"color": "93d49a", "label": "AWN-IX", "attributes": {}, "x": 11, "y": -343, "id": "AS45458", "size": 24}, {"color": "b640d8", "label": "Symphony-ISP", "attributes": {}, "x": -222, "y": -258, "id": "AS132280", "size": 4}, {"color": "4a0ae2", "label": "CAT-ISP", "attributes": {}, "x": -331, "y": 916, "id": "AS9931", "size": 2}, {"color": "a07216", "label": "INET", "attributes": {}, "x": 590, "y": -393, "id": "AS4618", "size": 8}, {"color": "ee15bc", "label": "Pacific Internet", "attributes": {}, "x": 832, "y": 692, "id": "AS4765", "size": 1}, {"color": "33912d", "label": "Ji-NET", "attributes": {}, "x": -646, "y": 246, "id": "AS7616", "size": 2}, {"color": "24073c", "label": "SAMART Infonet", "attributes": {}, "x": -741, "y": 312, "id": "AS4741", "size": 2}, {"color": "66c236", "label": "Triple T Internet/ Triple T Broadband", "attributes": {}, "x": 96, "y": -440, "id": "AS45758", "size": 5}, {"color": "18d886", "label": "KIRZ", "attributes": {}, "x": 204, "y": -134, "id": "AS24187", "size": 4}, {"color": "90fdfe", "label": "OTARO", "attributes": {}, "x": 632, "y": -378, "id": "AS23932", "size": 4}, {"color": "978036", "label": "ISSP", "attributes": {}, "x": -29, "y": -339, "id": "AS7654", "size": 2}, {"color": "03c312", "label": "ISSP", "attributes": {}, "x": 618, "y": -905, "id": "AS24299", "size": 1}, {"color": "4eec22", "label": "PROEN Internet", "attributes": {}, "x": 862, "y": -684, "id": "AS23884", "size": 6}, {"color": "6650de", "label": "True Internet Corporation", "attributes": {}, "x": 306, "y": 450, "id": "AS7470", "size": 3}, {"color": "4de285", "label": "Telstra", "attributes": {}, "x": -412, "y": 756, "id": "AS4637", "size": 1}, {"color": "84b6a7", "label": "KSC", "attributes": {}, "x": -695, "y": -942, "id": "AS7693", "size": 3}, {"color": "5f80a0", "label": "TOT ISP", "attributes": {}, "x": 142, "y": 540, "id": "AS23969", "size": 6}, {"color": "98958f", "label": "UIH/ BEENET", "attributes": {}, "x": 324, "y": -936, "id": "AS38794", "size": 4}, {"color": "741497", "label": "MILCOM", "attributes": {}, "x": -834, "y": -700, "id": "AS38888", "size": 1}, {"color": "4b9d80", "label": "Loxley", "attributes": {}, "x": -677, "y": -231, "id": "AS45142", "size": 2}, {"color": "b5b0fc", "label": "NIPA.CLOUD", "attributes": {}, "x": 313, "y": -714, "id": "AS45328", "size": 5}, {"color": "4ca669", "label": "101 Global", "attributes": {}, "x": 502, "y": -970, "id": "AS45606", "size": 1}, {"color": "347e3a", "label": "NTT (TH)", "attributes": {}, "x": 479, "y": -848, "id": "AS38566", "size": 4}, {"color": "4e48b2", "label": "TOT LLI", "attributes": {}, "x": -936, "y": 338, "id": "AS131293", "size": 2}, {"color": "ae8a49", "label": "CAT ON Net", "attributes": {}, "x": -689, "y": 387, "id": "AS131090", "size": 1}, {"color": "286032", "label": "ServeNET", "attributes": {}, "x": -245, "y": -858, "id": "AS45413", "size": 1}, {"color": "263eec", "label": "SIAMDATA", "attributes": {}, "x": -342, "y": -8, "id": "AS5639", "size": 2}, {"color": "d743d2", "label": "TCCT-ISP", "attributes": {}, "x": 819, "y": -572, "id": "AS17887", "size": 2}, {"color": "3da53c", "label": "INOX", "attributes": {}, "x": -866, "y": 919, "id": "AS59238", "size": 2}, {"color": "5ce4d4", "label": "UniNet", "attributes": {}, "x": 109, "y": 455, "id": "AS4621", "size": 3}, {"color": "7f956a", "label": "ICT MOF", "attributes": {}, "x": -310, "y": -941, "id": "AS38328", "size": 1}, {"color": "7f6d4c", "label": "Metrabyte", "attributes": {}, "x": 314, "y": 879, "id": "AS56067", "size": 1}, {"color": "a1ef8a", "label": "1-TO-ALL" ...
